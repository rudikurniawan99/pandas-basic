# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('dataset/Kickstarter+Projects/kickstarter_projects.csv')
df
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country             Launched  \
# ...

# %%
# pandas  data view
df.columns
df.index

# data with certain condition
# art project
paint_project = df[(df['Category'] == 'Art') & (df['Subcategory'] == 'Painting')]
paint_project.head(7)
# Out:
#              ID                                               Name Category  \
# 29    772300929                          "LostLES" at Tiny's Giant      Art
# 44    353710709                    Decorative Nihilism Art Catalog      Art
# 54    995325523                           Metaphysical Archaeology      Art
# 56     39739909  Choose Your Own Adventure - A Robot Painting S...      Art
# 113   725084811                      The Old Three Hundred Tribute      Art
# 126   247222418  Take a postcard trip with Anita as she waterco...      Art
# 181  1036167768                                         Cheap art!      Art
#
#     Subcategory        Country             Launched    Deadline  Goal  \
# 29     Painting  United States  2009-05-05 01:48:21  2009-06-06  5000
# 44     Painting  United States  2009-05-12 19:02:11  2009-07-01   100
# 54     Painting  United States  2009-05-13 19:00:27  2009-07-25  2000
# 56     Painting  United States  2009-05-14 05:57:40  2009-06-14  3500
# ...

# %%
# get list of the Country
country_list = paint_project['Country'].unique()
country_list.tolist()
# Out:
# ['United States',
#  'United Kingdom',
#  'Canada',
#  'Australia',
#  'New Zealand',
#  'Netherlands ',
#  'Denmark',
#  'Sweden',
#  'Norway',
#  'Ireland',
#  'Germany',
#  'Spain',
#  'Italy',
#  'France',
#  'Belgium',
#  'Switzerland',
#  'Austria',
#  'Mexico',
#  'Hong Kong']

# %%
# start new thread
tech_field = df[df['Category'] == 'Technology']
country_distribution = pd.DataFrame(tech_field['Country'].value_counts().reset_index())
country_distribution['percentage'] = (country_distribution['count']/country_distribution['count'].sum())*100
country_distribution.head(5)
# Out:
#           Country  count  percentage
# 0   United States  21556   66.199865
# 1  United Kingdom   3068    9.422026
# 2          Canada   1924    5.908728
# 3       Australia   1215    3.731343
# 4         Germany    839    2.576623

# %%
# Data Visualization
sns.catplot(
  data=country_distribution.head(5),
  x='Country',
  y='percentage',
  kind='bar'
)

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  object
#  2   Category     374853 non-null  object
#  3   Subcategory  374853 non-null  object
#  4   Country      374853 non-null  object
#  5   Launched     374853 non-null  object
#  6   Deadline     374853 non-null  object
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 31.5+ MB
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# ...

# %%
df['Deadline'] = pd.to_datetime(df['Deadline'])
df['Launched'] = pd.to_datetime(df['Launched'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  object
#  2   Category     374853 non-null  object
#  3   Subcategory  374853 non-null  object
#  4   Country      374853 non-null  object
#  5   Launched     374853 non-null  datetime64[ns]
#  6   Deadline     374853 non-null  datetime64[ns]
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  object
# dtypes: datetime64[ns](2), int64(4), object(5)
# memory usage: 31.5+ MB

# %%
import datetime

df['Deadline'].dt.year.value_counts()
year_distribution = pd.DataFrame(data=df['Deadline'].dt.year.value_counts().reset_index())
year_distribution['percent'] = (year_distribution['count']/year_distribution['count'].sum())
year_distribution
# Out:
#    Deadline  count   percent
# 0      2015  75174  0.200543
# 1      2014  65590  0.174975
# 2      2016  57257  0.152745
# 3      2017  52741  0.140698
# 4      2013  44162  0.117812
# 5      2012  41557  0.110862
# 6      2011  25106  0.066976
# 7      2010   9092  0.024255
# 8      2018   3272  0.008729
# 9      2009    902  0.002406

# %%
sns.scatterplot(
  data=year_distribution,
  x='Deadline',
  y='count',
  size='count'
)
# Out:
# <Axes: xlabel='Deadline', ylabel='count'>

# %%
df.tail()
# Out:
#                 ID                                               Name  \
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#        Category     Subcategory        Country            Launched   Deadline  \
# 374848    Music         Hip-Hop  United States 2018-01-02 14:13:09 2018-01-16
# 374849   Design  Product Design  United States 2018-01-02 14:15:38 2018-02-09
# 374850     Food            Food  United States 2018-01-02 14:17:46 2018-01-16
# 374851      Art             Art  United States 2018-01-02 14:38:17 2018-02-01
# 374852    Games  Tabletop Games          Spain 2018-01-02 15:02:31 2018-01-26
#
#          Goal  Pledged  Backers State
# ...
